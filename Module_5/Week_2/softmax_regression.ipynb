# %% [markdown]
# # 1. Credit Card Fraud Detection

# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 2. Read dataset

# %%
dataset_path = "/content/creditcard.csv"
df = pd.read_csv(dataset_path)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# # 3. Preprocess the data

# %%
# Convert data type
dataset_arr = df.to_numpy()

# Get inputs and label
X, y = dataset_arr[:, :-1].astype(np.float64), dataset_arr[:, -1].astype(np.uint8)

# Add intercept
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis=1)

# One-hot encoding
n_classes = np.unique(y, axis=0).shape[0]
n_samples = y.shape[0]

y_encoded = np.array([np.zeros(n_classes) for _ in range(n_samples)])
y_encoded[np.arange(n_samples), y] = 1

# %% [markdown]
# # 4. Split train, test from the data

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(X_b, y_encoded, test_size=val_size, random_state=random_state, shuffle=is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle)

# %% [markdown]
# # 5. Normalize the data

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %% [markdown]
# # 6. Build model

# %%
def softmax(z):
    exp_z = np.exp(z)

    return exp_z / exp_z.sum(axis=1)[:, None]

def predict(X, theta):
    z = np.dot(X, theta)
    y_hat = softmax(z)

    return y_hat

def compute_loss(y_hat, y):
    return (-1 / y.size) * np.sum(y * np.log(y_hat))

def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

def update_theta(theta, gradient, lr):
    return theta - lr * gradient

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta)
    acc = (np.argmax(y_hat, axis=1) == np.argmax(y, axis=1)).mean()

    return acc

# %% [markdown]
# # 7. Train the model

# %%
# Init parameters
lr = 0.01
epochs = 30
batch_size = 1024
n_features = X_train.shape[1]

np.random.seed(random_state)
theta = np.random.uniform(size=(n_features, n_classes))


# Train the model
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range (0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)
        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        # Compute losses and accs
        train_batch_losses.append(train_loss)
        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print (f"\nEPOCH {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}")
# Out:
# EPOCH 1:	Training loss: 0.300	Validation loss: 0.297
#
# EPOCH 2:	Training loss: 0.176	Validation loss: 0.174
#
# EPOCH 3:	Training loss: 0.115	Validation loss: 0.113
#
# EPOCH 4:	Training loss: 0.081	Validation loss: 0.080
#
# EPOCH 5:	Training loss: 0.062	Validation loss: 0.061
#
# EPOCH 6:	Training loss: 0.049	Validation loss: 0.049
#
# EPOCH 7:	Training loss: 0.041	Validation loss: 0.041
#
# EPOCH 8:	Training loss: 0.035	Validation loss: 0.035
#
# EPOCH 9:	Training loss: 0.031	Validation loss: 0.031
#
# EPOCH 10:	Training loss: 0.028	Validation loss: 0.027
#
# EPOCH 11:	Training loss: 0.025	Validation loss: 0.025
#
# EPOCH 12:	Training loss: 0.023	Validation loss: 0.023
#
# EPOCH 13:	Training loss: 0.021	Validation loss: 0.021
#
# EPOCH 14:	Training loss: 0.020	Validation loss: 0.020
#
# EPOCH 15:	Training loss: 0.019	Validation loss: 0.018
#
# EPOCH 16:	Training loss: 0.017	Validation loss: 0.017
#
# EPOCH 17:	Training loss: 0.017	Validation loss: 0.016
#
# EPOCH 18:	Training loss: 0.016	Validation loss: 0.015
#
# EPOCH 19:	Training loss: 0.015	Validation loss: 0.015
#
# EPOCH 20:	Training loss: 0.014	Validation loss: 0.014
#
# EPOCH 21:	Training loss: 0.014	Validation loss: 0.013
#
# EPOCH 22:	Training loss: 0.013	Validation loss: 0.013
#
# EPOCH 23:	Training loss: 0.013	Validation loss: 0.012
#
# EPOCH 24:	Training loss: 0.012	Validation loss: 0.012
#
# EPOCH 25:	Training loss: 0.012	Validation loss: 0.011
#
# EPOCH 26:	Training loss: 0.011	Validation loss: 0.011
#
# EPOCH 27:	Training loss: 0.011	Validation loss: 0.011
#
# EPOCH 28:	Training loss: 0.011	Validation loss: 0.010
#
# EPOCH 29:	Training loss: 0.010	Validation loss: 0.010
#
# EPOCH 30:	Training loss: 0.010	Validation loss: 0.010

# %% [markdown]
# # 8. Visualize the data

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel="Epoch", ylabel="Loss")
ax[0, 0].set_title("Training Loss")

ax[0, 1].plot(val_losses, "orange")
ax [0, 1].set(xlabel="Epoch", ylabel="Loss")
ax [0, 1].set_title("Validation Loss")

ax [1, 0].plot(train_accs)
ax [1, 0].set(xlabel="Epoch", ylabel="Accuracy")
ax [1, 0].set_title("Training Accuracy")

ax [1, 1].plot(val_accs, "orange")
ax [1, 1].set(xlabel="Epoch", ylabel="Accuracy")
ax [1, 1].set_title("Validation Accuracy")

plt.show()

# %% [markdown]
# ## 9. Evaluate the model

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print("Evaluation on validation and test set:")
print(f"Accuracy: {val_set_acc}")
print(f"Accuracy: {test_set_acc}")
# Out:
# Evaluation on validation and test set:
# Accuracy: 0.9993153330290369
# Accuracy: 0.9992275552122467

# %% [markdown]
# # II. Twitter Sentiment Analysis

# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
nltk.download("stopwords")

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 2. Read dataset

# %%
dataset_path = "/content/Twitter_Data.csv"
df = pd.read_csv(dataset_path)

# %%
df.describe()
# Out:
#             category
# count  162973.000000
# mean        0.225436
# std         0.781279
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# # 3. Preprocess the data

# %%
# Remove missing data
df = df.dropna()

# %%
# Normalize the text
def text_normalize(text):
    # Lowercasing
    text = text.lower()

    # Retweet old acronym "RT" removal
    text = re.sub(r"^RT[\s]+", "", text)

    # Hyperlinks removal
    text = re.sub(r"https?:\/\/.*[\r\n]*", "", text)

    # Punctuation removal
    text = re.sub(r"[^\w\s]", "", text)

    # Remove stopwords
    stop_words = set(stopwords.words("english"))
    words = text .split()
    words = [word for word in words if word not in stop_words]
    text = " ".join(words)

    # Stemming
    stemmer = SnowballStemmer ("english")
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    text = " ".join(words)

    return text

# %%
vectorizer = TfidfVectorizer(max_features=2000)
X = vectorizer.fit_transform(df["clean_text"]).toarray()

# Add intercept
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis=1)

# One-hot encoding
n_classes = df["category"].nunique()
n_samples = df["category"].size

y = df["category"].to_numpy() + 1
y = y.astype(np.uint8)
y_encoded = np.array([np.zeros(n_classes) for _ in range(n_samples)])
y_encoded[np.arange(n_samples), y] = 1

# %% [markdown]
# # 4. Split train, test from the data

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=val_size, random_state=random_state, shuffle=is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle)

# %% [markdown]
# # 5. Build model

# %%
def softmax(z):
    exp_z = np.exp(z)

    return exp_z / exp_z.sum(axis=1)[:, None]

def predict(X, theta):
    z = np.dot(X, theta)
    y_hat = softmax(z)

    return y_hat

def compute_loss(y_hat, y):
    return (-1 / y.size) * np.sum(y * np.log(y_hat))

def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

def update_theta(theta, gradient, lr):
    return theta - lr * gradient

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta)
    acc = (np.argmax(y_hat, axis=1) == np.argmax(y, axis=1)).mean()

    return acc

# %% [markdown]
# # 6. Train the model

# %%
# Init parameters
lr = 0.1
epochs = 200
batch_size = X_train.shape[0]
n_features = X_train.shape[1]

np.random.seed(random_state)
theta = np.random.uniform(size=(n_features, n_classes))


# Train the model
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range (0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)
        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        # Compute losses and accs
        train_batch_losses.append(train_loss)
        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print (f"\nEPOCH {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}")
# Out:
# EPOCH 1:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 2:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 3:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 4:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 5:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 6:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 7:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 8:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 9:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 10:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 11:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 12:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 13:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 14:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 15:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 16:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 17:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 18:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 19:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 20:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 21:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 22:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 23:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 24:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 25:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 26:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 27:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 28:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 29:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 30:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 31:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 32:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 33:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 34:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 35:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 36:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 37:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 38:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 39:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 40:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 41:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 42:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 43:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 44:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 45:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 46:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 47:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 48:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 49:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 50:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 51:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 52:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 53:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 54:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 55:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 56:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 57:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 58:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 59:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 60:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 61:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 62:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 63:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 64:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 65:	Training loss: 0.370	Validation loss: 0.370
#
# EPOCH 66:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 67:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 68:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 69:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 70:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 71:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 72:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 73:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 74:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 75:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 76:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 77:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 78:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 79:	Training loss: 0.370	Validation loss: 0.369
#
# EPOCH 80:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 81:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 82:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 83:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 84:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 85:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 86:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 87:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 88:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 89:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 90:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 91:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 92:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 93:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 94:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 95:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 96:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 97:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 98:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 99:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 100:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 101:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 102:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 103:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 104:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 105:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 106:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 107:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 108:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 109:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 110:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 111:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 112:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 113:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 114:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 115:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 116:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 117:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 118:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 119:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 120:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 121:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 122:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 123:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 124:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 125:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 126:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 127:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 128:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 129:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 130:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 131:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 132:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 133:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 134:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 135:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 136:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 137:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 138:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 139:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 140:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 141:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 142:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 143:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 144:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 145:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 146:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 147:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 148:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 149:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 150:	Training loss: 0.369	Validation loss: 0.369
#
# EPOCH 151:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 152:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 153:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 154:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 155:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 156:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 157:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 158:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 159:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 160:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 161:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 162:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 163:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 164:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 165:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 166:	Training loss: 0.369	Validation loss: 0.368
#
# EPOCH 167:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 168:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 169:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 170:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 171:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 172:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 173:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 174:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 175:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 176:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 177:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 178:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 179:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 180:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 181:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 182:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 183:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 184:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 185:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 186:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 187:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 188:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 189:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 190:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 191:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 192:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 193:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 194:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 195:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 196:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 197:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 198:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 199:	Training loss: 0.368	Validation loss: 0.368
#
# EPOCH 200:	Training loss: 0.368	Validation loss: 0.368

# %% [markdown]
# # 7. Visualize the data

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel="Epoch", ylabel="Loss")
ax[0, 0].set_title("Training Loss")

ax[0, 1].plot(val_losses, "orange")
ax [0, 1].set(xlabel="Epoch", ylabel="Loss")
ax [0, 1].set_title("Validation Loss")

ax [1, 0].plot(train_accs)
ax [1, 0].set(xlabel="Epoch", ylabel="Accuracy")
ax [1, 0].set_title("Training Accuracy")

ax [1, 1].plot(val_accs, "orange")
ax [1, 1].set(xlabel="Epoch", ylabel="Accuracy")
ax [1, 1].set_title("Validation Accuracy")

plt.show()

# %% [markdown]
# # 8. Evaluate the model

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print("Evaluation on validation and test set:")
print(f"Accuracy: {val_set_acc}")
print(f"Accuracy: {test_set_acc}")
# Out:
# Evaluation on validation and test set:
# Accuracy: 0.37273731361600293
# Accuracy: 0.3698226667484813
